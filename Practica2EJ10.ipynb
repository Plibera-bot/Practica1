# %%
rounds = [
    {
        'theme':'Entrada',
        'scores':{
            'Valentina':{'judge_1':8,'judge_2':7,'judge_3':9},
            'Mateo':{'judge_1':7,'judge_2':8,'judge_3':7},
            'Camila':{'judge_1':9,'judge_2':9,'judge_3':8},
            'Santiago':{'judge_1':6,'judge_2':7,'judge_3':6},
            'Lucia':{'judge_1':8,'judge_2':8,'judge_3':8},
        }
    },
    {
        'theme':'Plato principal',
        'scores':{
            'Valentina':{'judge_1':9,'judge_2':9,'judge_3':8},
            'Mateo':{'judge_1':8,'judge_2':7,'judge_3':9},
            'Camila':{'judge_1':7,'judge_2':6,'judge_3':7},
            'Santiago':{'judge_1':9,'judge_2':8,'judge_3':8},
            'Lucia':{'judge_1':7,'judge_2':8,'judge_3':7},
        }
    },
    {'theme':'Postre',
     'scores':{
         'Valentina':{'judge_1':7,'judge_2':8,'judge_3':7},
         'Mateo':{'judge_1':9,'judge_2':9,'judge_3':8},
         'Camila':{'judge_1':8,'judge_2':7,'judge_3':9},
         'Santiago':{'judge_1':7,'judge_2':7,'judge_3':6},
         'Lucia':{'judge_1':9,'judge_2':9,'judge_3':9},
     }
    },
    {
        'theme':'Cocina internacional',
        'scores':{
            'Valentina':{'judge_1':8,'judge_2':9,'judge_3':9},
            'Mateo':{'judge_1':7,'judge_2':6,'judge_3':7},
            'Camila':{'judge_1':9,'judge_2':8,'judge_3':8},
            'Santiago':{'judge_1':8,'judge_2':9,'judge_3':7},
            'Lucia':{'judge_1':7,'judge_2':7,'judge_3':8},
        }
    },
    {
        'theme':'Final libre',
        'scores':{
            'Valentina':{'judge_1':9,'judge_2':8,'judge_3':9},
            'Mateo':{'judge_1':8,'judge_2':9,'judge_3':8},
            'Camila':{'judge_1':7,'judge_2':7,'judge_3':7},
            'Santiago':{'judge_1':9,'judge_2':9,'judge_3':9},
            'Lucia':{'judge_1':8,'judge_2':8,'judge_3':7},
        }
    }
]

# %%
tabla_posiciones = {'Valentina':{'Puntaje':0,'Rondas ganadas':0,'Mejor ronda':0,'Promedio':0},
                   'Mateo':{'Puntaje':0,'Rondas ganadas':0,'Mejor ronda':0,'Promedio':0},
                   'Santiago':{'Puntaje':0,'Rondas ganadas':0,'Mejor ronda':0,'Promedio':0},
                   'Camila':{'Puntaje':0,'Rondas ganadas':0,'Mejor ronda':0,'Promedio':0},
                   'Lucia':{'Puntaje':0,'Rondas ganadas':0,'Mejor ronda':0,'Promedio':0}}
num=0
for round in rounds:
    num=num+1
    max_puntaje=0
    for participante in round['scores']:
        puntaje_ronda=0
        for juez, puntaje in round['scores'][participante].items():
            puntaje_ronda= puntaje_ronda + puntaje
        if(tabla_posiciones[participante]['Mejor ronda']<puntaje_ronda):
            tabla_posiciones[participante]['Mejor ronda']=puntaje_ronda
        tabla_posiciones[participante]['Puntaje'] = tabla_posiciones[participante]['Puntaje'] + puntaje_ronda
        if(max_puntaje<puntaje_ronda):
            max_puntaje=puntaje_ronda
            ganador_ronda=participante
    tabla_posiciones[ganador_ronda]['Rondas ganadas']=tabla_posiciones[ganador_ronda]['Rondas ganadas']+1
    for participante in tabla_posiciones:
        tabla_posiciones[participante]['Promedio']=tabla_posiciones[participante]['Puntaje']/5
    print('Ronda', num,' - ',round['theme'],':')
    print('ganador: ',ganador_ronda,' (',max_puntaje,'pts)')   
    print(f'{'Cocinero':<20}{'Puntaje':<20}{'Rondas ganadas':<20}{'Mejor ronda':<20}{'Promedio':<20}')
    print('-'*90)
    for participante in tabla_posiciones:
        print(f"{participante:<20}", end="")
        for valor in tabla_posiciones[participante].values():
            print(f"{valor:<20}", end="")
    print('-'*90)
print('Tabla de posiciones final:')
print(f'{'Cocinero':<20}{'Puntaje':<20}{'Rondas ganadas':<20}{'Mejor ronda':<20}{'Promedio':<20}')
print('-'*90)
for participante, datos in ordenados:
    print(f"{participante:<20}", end="")
    for valor in datos.values():
        print(f"{valor:<20}", end="")
print('-'*90)
# Out:
# Ronda 1  -  Entrada :
# ganador:  Camila  ( 26 pts)
# Cocinero            Puntaje             Rondas ganadas      Mejor ronda         Promedio
# ------------------------------------------------------------------------------------------
# Valentina           24                  0                   24                  4.8                 Mateo               22                  0                   22                  4.4                 Santiago            19                  0                   19                  3.8                 Camila              26                  1                   26                  5.2                 Lucia               24                  0                   24                  4.8                 ------------------------------------------------------------------------------------------
# Ronda 2  -  Plato principal :
# ganador:  Valentina  ( 26 pts)
# Cocinero            Puntaje             Rondas ganadas      Mejor ronda         Promedio
# ------------------------------------------------------------------------------------------
# Valentina           50                  1                   26                  10.0                Mateo               46                  0                   24                  9.2                 Santiago            44                  0                   25                  8.8                 Camila              46                  1                   26                  9.2                 Lucia               46                  0                   24                  9.2                 ------------------------------------------------------------------------------------------
# Ronda 3  -  Postre :
# ganador:  Lucia  ( 27 pts)
# Cocinero            Puntaje             Rondas ganadas      Mejor ronda         Promedio
# ------------------------------------------------------------------------------------------
# Valentina           72                  1                   26                  14.4                Mateo               72                  0                   26                  14.4                Santiago            64                  0                   25                  12.8                Camila              70                  1                   26                  14.0                Lucia               73                  1                   27                  14.6                ------------------------------------------------------------------------------------------
# Ronda 4  -  Cocina internacional :
# ganador:  Valentina  ( 26 pts)
# Cocinero            Puntaje             Rondas ganadas      Mejor ronda         Promedio
# ------------------------------------------------------------------------------------------
# Valentina           98                  2                   26                  19.6                Mateo               92                  0                   26                  18.4                Santiago            88                  0                   25                  17.6                Camila              95                  1                   26                  19.0                Lucia               95                  1                   27                  19.0                ------------------------------------------------------------------------------------------
# Ronda 5  -  Final libre :
# ganador:  Santiago  ( 27 pts)
# Cocinero            Puntaje             Rondas ganadas      Mejor ronda         Promedio
# ------------------------------------------------------------------------------------------
# Valentina           124                 2                   26                  24.8                Mateo               117                 0                   26                  23.4                Santiago            115                 1                   27                  23.0                Camila              116                 1                   26                  23.2                Lucia               118                 1                   27                  23.6                ------------------------------------------------------------------------------------------
# Tabla de posiciones final:
# Cocinero            Puntaje             Rondas ganadas      Mejor ronda         Promedio
# ------------------------------------------------------------------------------------------
# Valentina           124                 2                   26                  24.8                Lucia               118                 1                   27                  23.6                Mateo               117                 0                   26                  23.4                Camila              116                 1                   26                  23.2                Santiago            115                 1                   27                  23.0                ------------------------------------------------------------------------------------------

# %%
ordenados = sorted(
    tabla_posiciones.items(),
    key=lambda x: x[1]["Puntaje"],
    reverse=True
)
